# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# Declare each array as a variable. lats and lngs

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes and longitudes as pairs by zipping them (lat_lngs) with the zip() function.
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple.

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.

from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 726

# %%
# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 

import time

# Import the datetime module from the datetime library.

from datetime import datetime

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")


# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):
    

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(10)
        

    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.

    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | lalmohan
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | exaplatanos
# Processing Record 8 of Set 1 | bonoua
# Processing Record 9 of Set 1 | fare
# Processing Record 10 of Set 1 | nikolayevsk-na-amure
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | berlevag
# Processing Record 20 of Set 1 | masvingo
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | mogadishu
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | marathon
# Processing Record 35 of Set 1 | praia
# Processing Record 36 of Set 1 | puerto baquerizo moreno
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | kahului
# Processing Record 39 of Set 1 | kavaratti
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | andra
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | westport
# Processing Record 44 of Set 1 | kasulu
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | nioro
# Processing Record 49 of Set 1 | ancud
# Processing Record 50 of Set 1 | bilma
# Processing Record 1 of Set 2 | batagay-alyta
# Processing Record 2 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 2 | carutapera
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | nanakuli
# Processing Record 6 of Set 2 | empalme
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | pamanukan
# Processing Record 9 of Set 2 | sisimiut
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | srandakan
# Processing Record 13 of Set 2 | palasa
# Processing Record 14 of Set 2 | moctezuma
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | puerto colombia
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | talakan
# Processing Record 21 of Set 2 | kloulklubed
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | brandon
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | klaksvik
# Processing Record 28 of Set 2 | neryungri
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | skelleftea
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | vila velha
# Processing Record 34 of Set 2 | katsina
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | dillon
# Processing Record 39 of Set 2 | portland
# Processing Record 40 of Set 2 | dalbandin
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | dutse
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | vedasandur
# Processing Record 45 of Set 2 | ostersund
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | santa cruz
# Processing Record 48 of Set 2 | greenwood
# Processing Record 49 of Set 2 | esna
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | shimanovsk
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | montrose
# Processing Record 5 of Set 3 | abu zabad
# Processing Record 6 of Set 3 | waki
# Processing Record 7 of Set 3 | kamenka
# Processing Record 8 of Set 3 | virginia beach
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | huarmey
# Processing Record 12 of Set 3 | nizhniy kuranakh
# Processing Record 13 of Set 3 | fukue
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 3 | zhuzhou
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | qasigiannguit
# Processing Record 19 of Set 3 | boende
# Processing Record 20 of Set 3 | kozhva
# Processing Record 21 of Set 3 | vila
# Processing Record 22 of Set 3 | hofn
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | sibolga
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | weyburn
# Processing Record 28 of Set 3 | marataizes
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | mpika
# Processing Record 31 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 3 | abu samrah
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | fayaoue
# Processing Record 36 of Set 3 | acarau
# Processing Record 37 of Set 3 | kenora
# Processing Record 38 of Set 3 | verkhnyaya inta
# Processing Record 39 of Set 3 | skjervoy
# Processing Record 40 of Set 3 | davidson
# Processing Record 41 of Set 3 | ambikapur
# Processing Record 42 of Set 3 | evensk
# Processing Record 43 of Set 3 | pitimbu
# Processing Record 44 of Set 3 | caxito
# Processing Record 45 of Set 3 | perth
# Processing Record 46 of Set 3 | havre-saint-pierre
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | lompoc
# Processing Record 1 of Set 4 | port-cartier
# Processing Record 2 of Set 4 | opuwo
# Processing Record 3 of Set 4 | kudahuvadhoo
# Processing Record 4 of Set 4 | oistins
# Processing Record 5 of Set 4 | andarab
# City not found. Skipping...
# Processing Record 6 of Set 4 | bhadrachalam
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | bowmore
# Processing Record 9 of Set 4 | mayor pablo lagerenza
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | byron bay
# Processing Record 12 of Set 4 | yar-sale
# Processing Record 13 of Set 4 | panama city
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | hongjiang
# Processing Record 17 of Set 4 | buala
# Processing Record 18 of Set 4 | maceio
# Processing Record 19 of Set 4 | kilindoni
# Processing Record 20 of Set 4 | sassandra
# Processing Record 21 of Set 4 | mokhotlong
# Processing Record 22 of Set 4 | xiaoweizhai
# Processing Record 23 of Set 4 | kirakira
# Processing Record 24 of Set 4 | komsomolskiy
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | nampula
# Processing Record 27 of Set 4 | okato
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | suntar
# Processing Record 31 of Set 4 | manaure
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | canakkale
# Processing Record 34 of Set 4 | ola
# Processing Record 35 of Set 4 | norsup
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | waingapu
# Processing Record 39 of Set 4 | collie
# Processing Record 40 of Set 4 | mana
# Processing Record 41 of Set 4 | puerto leguizamo
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | gari
# Processing Record 44 of Set 4 | dalinghe
# City not found. Skipping...
# Processing Record 45 of Set 4 | honiara
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | kissidougou
# Processing Record 48 of Set 4 | mookane
# Processing Record 49 of Set 4 | hambantota
# Processing Record 50 of Set 4 | fort nelson
# Processing Record 1 of Set 5 | roma
# Processing Record 2 of Set 5 | xam nua
# Processing Record 3 of Set 5 | havoysund
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | teguise
# Processing Record 6 of Set 5 | kailua
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 | ketchikan
# Processing Record 10 of Set 5 | collipulli
# Processing Record 11 of Set 5 | paka
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | daru
# Processing Record 15 of Set 5 | betma
# Processing Record 16 of Set 5 | aguimes
# Processing Record 17 of Set 5 | mayo
# Processing Record 18 of Set 5 | kavadarci
# Processing Record 19 of Set 5 | alta floresta
# Processing Record 20 of Set 5 | meadow lake
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | karratha
# Processing Record 23 of Set 5 | biak
# Processing Record 24 of Set 5 | kamina
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | muros
# Processing Record 27 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 5 | kerema
# Processing Record 29 of Set 5 | solnechnyy
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | kutum
# Processing Record 33 of Set 5 | puerto escondido
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | sinnamary
# Processing Record 36 of Set 5 | isangel
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | mandalgovi
# Processing Record 39 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 5 | cabo san lucas
# Processing Record 41 of Set 5 | bubaque
# Processing Record 42 of Set 5 | inhambane
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | bireun
# Processing Record 46 of Set 5 | kaitong
# Processing Record 47 of Set 5 | kushima
# Processing Record 48 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | svetlogorsk
# Processing Record 50 of Set 5 | beyla
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | murupara
# Processing Record 3 of Set 6 | mehamn
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | norrtalje
# Processing Record 7 of Set 6 | turtas
# Processing Record 8 of Set 6 | ixtapa
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | senanga
# Processing Record 11 of Set 6 | mahebourg
# Processing Record 12 of Set 6 | bella vista
# Processing Record 13 of Set 6 | teacapan
# Processing Record 14 of Set 6 | saint-ambroise
# Processing Record 15 of Set 6 | dunedin
# Processing Record 16 of Set 6 | shitkino
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | caravelas
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 22 of Set 6 | goderich
# Processing Record 23 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | ormara
# Processing Record 25 of Set 6 | tsiroanomandidy
# Processing Record 26 of Set 6 | santa maria
# Processing Record 27 of Set 6 | nelson bay
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | kaeo
# Processing Record 30 of Set 6 | linares
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | necochea
# Processing Record 33 of Set 6 | vitim
# Processing Record 34 of Set 6 | pimenta bueno
# Processing Record 35 of Set 6 | sorong
# Processing Record 36 of Set 6 | usinsk
# Processing Record 37 of Set 6 | viloco
# Processing Record 38 of Set 6 | aloleng
# Processing Record 39 of Set 6 | qaanaaq
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | stantsionno-oyashinskiy
# Processing Record 44 of Set 6 | omsukchan
# Processing Record 45 of Set 6 | tabou
# Processing Record 46 of Set 6 | tuktoyaktuk
# Processing Record 47 of Set 6 | yumen
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | samana
# Processing Record 50 of Set 6 | galle
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | buraydah
# Processing Record 3 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | okha
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | dukat
# Processing Record 8 of Set 7 | twentynine palms
# Processing Record 9 of Set 7 | wahlern
# Processing Record 10 of Set 7 | ontario
# Processing Record 11 of Set 7 | port blair
# Processing Record 12 of Set 7 | bananeiras
# Processing Record 13 of Set 7 | lenger
# Processing Record 14 of Set 7 | elizabeth city
# Processing Record 15 of Set 7 | nipawin
# Processing Record 16 of Set 7 | murgab
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | nechi
# Processing Record 20 of Set 7 | almenara
# Processing Record 21 of Set 7 | paragominas
# Processing Record 22 of Set 7 | maracas
# Processing Record 23 of Set 7 | shache
# Processing Record 24 of Set 7 | amga
# Processing Record 25 of Set 7 | namibe
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | doha
# Processing Record 28 of Set 7 | saint-augustin
# Processing Record 29 of Set 7 | nadym
# Processing Record 30 of Set 7 | qiongshan
# Processing Record 31 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 7 | san jose de rio tinto
# Processing Record 33 of Set 7 | san angelo
# Processing Record 34 of Set 7 | arteaga
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | okhotsk
# Processing Record 37 of Set 7 | russell
# Processing Record 38 of Set 7 | vestmanna
# Processing Record 39 of Set 7 | zaozhuang
# Processing Record 40 of Set 7 | luganville
# Processing Record 41 of Set 7 | douglas
# Processing Record 42 of Set 7 | mishelevka
# Processing Record 43 of Set 7 | bilibino
# Processing Record 44 of Set 7 | kongoussi
# Processing Record 45 of Set 7 | adrar
# Processing Record 46 of Set 7 | mashhad
# Processing Record 47 of Set 7 | sao raimundo nonato
# Processing Record 48 of Set 7 | turukhansk
# Processing Record 49 of Set 7 | letlhakeng
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | oktyabrskiy
# Processing Record 2 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 8 | chinhoyi
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | baruun-urt
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sabang
# Processing Record 8 of Set 8 | arlit
# Processing Record 9 of Set 8 | mabai
# Processing Record 10 of Set 8 | samarai
# Processing Record 11 of Set 8 | starup
# Processing Record 12 of Set 8 | arcachon
# Processing Record 13 of Set 8 | pointe michel
# Processing Record 14 of Set 8 | cubara
# Processing Record 15 of Set 8 | clara
# Processing Record 16 of Set 8 | bud
# Processing Record 17 of Set 8 | bambanglipuro
# Processing Record 18 of Set 8 | rutland
# Processing Record 19 of Set 8 | dongning
# Processing Record 20 of Set 8 | ewa beach
# Processing Record 21 of Set 8 | bolshoye kozino
# City not found. Skipping...
# Processing Record 22 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 8 | athabasca
# Processing Record 24 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 25 of Set 8 | shingu
# Processing Record 26 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 8 | ibra
# Processing Record 29 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 8 | serenje
# Processing Record 33 of Set 8 | mount isa
# Processing Record 34 of Set 8 | qianguo
# Processing Record 35 of Set 8 | beyneu
# Processing Record 36 of Set 8 | polunochnoye
# Processing Record 37 of Set 8 | hirado
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | shimoda
# Processing Record 40 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 8 | itoman
# Processing Record 42 of Set 8 | concordia
# Processing Record 43 of Set 8 | pevek
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | gao
# Processing Record 46 of Set 8 | fairbanks
# Processing Record 47 of Set 8 | chimore
# Processing Record 48 of Set 8 | sidi ali
# Processing Record 49 of Set 8 | olinda
# Processing Record 50 of Set 8 | apiai
# Processing Record 1 of Set 9 | lugo
# Processing Record 2 of Set 9 | tanete
# Processing Record 3 of Set 9 | christchurch
# Processing Record 4 of Set 9 | pemangkat
# Processing Record 5 of Set 9 | lovozero
# Processing Record 6 of Set 9 | bathsheba
# Processing Record 7 of Set 9 | winneba
# Processing Record 8 of Set 9 | manta
# Processing Record 9 of Set 9 | kalmunai
# Processing Record 10 of Set 9 | mobai
# Processing Record 11 of Set 9 | sao jose da coroa grande
# Processing Record 12 of Set 9 | ambilobe
# Processing Record 13 of Set 9 | touros
# Processing Record 14 of Set 9 | davenport
# Processing Record 15 of Set 9 | hobyo
# Processing Record 16 of Set 9 | san policarpo
# Processing Record 17 of Set 9 | puerto suarez
# Processing Record 18 of Set 9 | half moon bay
# Processing Record 19 of Set 9 | shaoyang
# Processing Record 20 of Set 9 | makakilo city
# Processing Record 21 of Set 9 | almaznyy
# Processing Record 22 of Set 9 | griffith
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | neiafu
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | clyde river
# Processing Record 27 of Set 9 | urucui
# Processing Record 28 of Set 9 | gravdal
# Processing Record 29 of Set 9 | naifaru
# Processing Record 30 of Set 9 | oliva
# Processing Record 31 of Set 9 | camacha
# Processing Record 32 of Set 9 | casablanca
# Processing Record 33 of Set 9 | cockburn town
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | prado
# Processing Record 37 of Set 9 | guerrero negro
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | ejura
# Processing Record 40 of Set 9 | cidreira
# Processing Record 41 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 9 | san andres
# Processing Record 43 of Set 9 | machesney park
# Processing Record 44 of Set 9 | klyuchi
# Processing Record 45 of Set 9 | lander
# Processing Record 46 of Set 9 | dzhebariki-khaya
# Processing Record 47 of Set 9 | maniitsoq
# Processing Record 48 of Set 9 | zemio
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | yokaichiba
# Processing Record 1 of Set 10 | veshenskaya
# Processing Record 2 of Set 10 | bonavista
# Processing Record 3 of Set 10 | nybro
# Processing Record 4 of Set 10 | tautira
# Processing Record 5 of Set 10 | maimon
# City not found. Skipping...
# Processing Record 6 of Set 10 | sioux lookout
# Processing Record 7 of Set 10 | port hardy
# Processing Record 8 of Set 10 | maroantsetra
# Processing Record 9 of Set 10 | utete
# Processing Record 10 of Set 10 | sabzevar
# Processing Record 11 of Set 10 | egvekinot
# Processing Record 12 of Set 10 | tekirdag
# Processing Record 13 of Set 10 | vanderhoof
# Processing Record 14 of Set 10 | aripuana
# Processing Record 15 of Set 10 | sao joao da barra
# Processing Record 16 of Set 10 | bardiyah
# Processing Record 17 of Set 10 | carmen
# Processing Record 18 of Set 10 | kerman
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | itaquyry
# Processing Record 21 of Set 10 | hauterive
# Processing Record 22 of Set 10 | namatanai
# Processing Record 23 of Set 10 | charlestown
# Processing Record 24 of Set 10 | ormond beach
# Processing Record 25 of Set 10 | san carlos de bariloche
# Processing Record 26 of Set 10 | snezhnogorsk
# Processing Record 27 of Set 10 | rocha
# Processing Record 28 of Set 10 | akhtanizovskaya
# Processing Record 29 of Set 10 | yashkul
# Processing Record 30 of Set 10 | guerrero
# Processing Record 31 of Set 10 | roebourne
# Processing Record 32 of Set 10 | rundu
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | novikovo
# Processing Record 35 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | conselheiro pena
# Processing Record 37 of Set 10 | kulhudhuffushi
# Processing Record 38 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 10 | izhma
# Processing Record 40 of Set 10 | quelimane
# Processing Record 41 of Set 10 | sesimbra
# Processing Record 42 of Set 10 | arys
# Processing Record 43 of Set 10 | baykit
# Processing Record 44 of Set 10 | beringovskiy
# Processing Record 45 of Set 10 | pirojpur
# Processing Record 46 of Set 10 | sangar
# Processing Record 47 of Set 10 | lebu
# Processing Record 48 of Set 10 | sitka
# Processing Record 49 of Set 10 | atbasar
# Processing Record 50 of Set 10 | vanimo
# Processing Record 1 of Set 11 | faanui
# Processing Record 2 of Set 11 | broome
# Processing Record 3 of Set 11 | gvarv
# Processing Record 4 of Set 11 | turkan
# Processing Record 5 of Set 11 | eyl
# Processing Record 6 of Set 11 | mahibadhoo
# Processing Record 7 of Set 11 | gizo
# Processing Record 8 of Set 11 | mackay
# Processing Record 9 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | burnie
# Processing Record 12 of Set 11 | prachuap khiri khan
# Processing Record 13 of Set 11 | cangzhou
# Processing Record 14 of Set 11 | anadyr
# Processing Record 15 of Set 11 | lodja
# Processing Record 16 of Set 11 | florida
# Processing Record 17 of Set 11 | yurga
# Processing Record 18 of Set 11 | noumea
# Processing Record 19 of Set 11 | verkhnevilyuysk
# Processing Record 20 of Set 11 | ostrovnoy
# Processing Record 21 of Set 11 | alice springs
# Processing Record 22 of Set 11 | buin
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | galveston
# Processing Record 25 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 11 | plettenberg bay
# Processing Record 27 of Set 11 | kabo
# Processing Record 28 of Set 11 | nouadhibou
# Processing Record 29 of Set 11 | bucksport
# Processing Record 30 of Set 11 | jalu
# Processing Record 31 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 11 | lasa
# Processing Record 33 of Set 11 | ishinomaki
# Processing Record 34 of Set 11 | portree
# Processing Record 35 of Set 11 | celestun
# Processing Record 36 of Set 11 | maxixe
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | kisanga
# Processing Record 39 of Set 11 | colares
# Processing Record 40 of Set 11 | matara
# Processing Record 41 of Set 11 | cap malheureux
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | kampot
# Processing Record 44 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 11 | thuro
# City not found. Skipping...
# Processing Record 46 of Set 11 | deputatskiy
# Processing Record 47 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 48 of Set 11 | pauini
# Processing Record 49 of Set 11 | dingle
# Processing Record 50 of Set 11 | dicabisagan
# Processing Record 1 of Set 12 | diu
# Processing Record 2 of Set 12 | biskamzha
# Processing Record 3 of Set 12 | riyadh
# Processing Record 4 of Set 12 | alyangula
# Processing Record 5 of Set 12 | kankan
# Processing Record 6 of Set 12 | sumbe
# Processing Record 7 of Set 12 | phan thiet
# Processing Record 8 of Set 12 | srednekolymsk
# Processing Record 9 of Set 12 | mina
# Processing Record 10 of Set 12 | lebyazhye
# Processing Record 11 of Set 12 | camocim
# Processing Record 12 of Set 12 | xichang
# Processing Record 13 of Set 12 | san cristobal
# Processing Record 14 of Set 12 | palmer
# Processing Record 15 of Set 12 | romani
# Processing Record 16 of Set 12 | annan
# Processing Record 17 of Set 12 | itaporanga
# Processing Record 18 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 12 | luderitz
# Processing Record 21 of Set 12 | neuquen
# Processing Record 22 of Set 12 | mpulungu
# Processing Record 23 of Set 12 | remontnoye
# Processing Record 24 of Set 12 | margate
# Processing Record 25 of Set 12 | kesan
# Processing Record 26 of Set 12 | brae
# Processing Record 27 of Set 12 | vidim
# Processing Record 28 of Set 12 | vostok
# Processing Record 29 of Set 12 | rio grande
# Processing Record 30 of Set 12 | oksfjord
# Processing Record 31 of Set 12 | jertih
# Processing Record 32 of Set 12 | raha
# Processing Record 33 of Set 12 | mezen
# Processing Record 34 of Set 12 | sao bernardo
# Processing Record 35 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 12 | chepareria
# Processing Record 37 of Set 12 | thinadhoo
# Processing Record 38 of Set 12 | aswan
# Processing Record 39 of Set 12 | rosetown
# Processing Record 40 of Set 12 | merauke
# Processing Record 41 of Set 12 | dire
# Processing Record 42 of Set 12 | rabo de peixe
# Processing Record 43 of Set 12 | presidencia roque saenz pena
# Processing Record 44 of Set 12 | nayoro
# Processing Record 45 of Set 12 | zhengjiatun
# Processing Record 46 of Set 12 | homer
# Processing Record 47 of Set 12 | port macquarie
# Processing Record 48 of Set 12 | elat
# Processing Record 49 of Set 12 | jamtara
# Processing Record 50 of Set 12 | dongli
# Processing Record 1 of Set 13 | qixia
# Processing Record 2 of Set 13 | estevan
# Processing Record 3 of Set 13 | mundra
# Processing Record 4 of Set 13 | festus
# Processing Record 5 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 13 | ariquemes
# Processing Record 7 of Set 13 | qandala
# Processing Record 8 of Set 13 | buriti alegre
# Processing Record 9 of Set 13 | mandera
# Processing Record 10 of Set 13 | george
# Processing Record 11 of Set 13 | weatherford
# Processing Record 12 of Set 13 | asau
# Processing Record 13 of Set 13 | inirida
# Processing Record 14 of Set 13 | smidovich
# Processing Record 15 of Set 13 | ust-maya
# Processing Record 16 of Set 13 | moindou
# Processing Record 17 of Set 13 | shchigry
# Processing Record 18 of Set 13 | aykhal
# Processing Record 19 of Set 13 | pontian kecil
# Processing Record 20 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 21 of Set 13 | kuliyapitiya
# Processing Record 22 of Set 13 | sal rei
# Processing Record 23 of Set 13 | williston
# Processing Record 24 of Set 13 | kaabong
# Processing Record 25 of Set 13 | olavarria
# Processing Record 26 of Set 13 | eregli
# Processing Record 27 of Set 13 | kindu
# Processing Record 28 of Set 13 | cartagena
# Processing Record 29 of Set 13 | dubti
# Processing Record 30 of Set 13 | zarubino
# Processing Record 31 of Set 13 | alofi
# Processing Record 32 of Set 13 | saravan
# Processing Record 33 of Set 13 | tornio
# Processing Record 34 of Set 13 | ossora
# Processing Record 35 of Set 13 | dongsheng
# Processing Record 36 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 37 of Set 13 | kolosovka
# Processing Record 38 of Set 13 | porto walter
# Processing Record 39 of Set 13 | bridlington
# Processing Record 40 of Set 13 | otane
# Processing Record 41 of Set 13 | palauig
# Processing Record 42 of Set 13 | tura
# Processing Record 43 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 13 | mumbwa
# Processing Record 45 of Set 13 | kieta
# Processing Record 46 of Set 13 | erdenet
# Processing Record 47 of Set 13 | coronado
# Processing Record 48 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 13 | dire dawa
# Processing Record 50 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 14 | port-gentil
# Processing Record 2 of Set 14 | velikie luki
# City not found. Skipping...
# Processing Record 3 of Set 14 | ouegoa
# Processing Record 4 of Set 14 | chekmagush
# Processing Record 5 of Set 14 | kalispell
# Processing Record 6 of Set 14 | balkhash
# Processing Record 7 of Set 14 | aguascalientes
# Processing Record 8 of Set 14 | juegang
# Processing Record 9 of Set 14 | banjar
# Processing Record 10 of Set 14 | kayerkan
# Processing Record 11 of Set 14 | posse
# Processing Record 12 of Set 14 | sitio novo do tocantins
# Processing Record 13 of Set 14 | dakar
# Processing Record 14 of Set 14 | kaspiyskiy
# Processing Record 15 of Set 14 | fougamou
# Processing Record 16 of Set 14 | ambulu
# Processing Record 17 of Set 14 | anchorage
# Processing Record 18 of Set 14 | dandong
# Processing Record 19 of Set 14 | lerik
# Processing Record 20 of Set 14 | auray
# Processing Record 21 of Set 14 | alghero
# Processing Record 22 of Set 14 | uruzgan
# Processing Record 23 of Set 14 | mangrol
# Processing Record 24 of Set 14 | bay-khaak
# Processing Record 25 of Set 14 | verkh-chebula
# Processing Record 26 of Set 14 | xuddur
# Processing Record 27 of Set 14 | sernovodskoye
# Processing Record 28 of Set 14 | kununurra
# Processing Record 29 of Set 14 | pangody
# Processing Record 30 of Set 14 | wadi musa
# Processing Record 31 of Set 14 | dubuque
# Processing Record 32 of Set 14 | suicheng
# Processing Record 33 of Set 14 | turan
# Processing Record 34 of Set 14 | pinawa
# Processing Record 35 of Set 14 | mahon
# Processing Record 36 of Set 14 | manokwari
# Processing Record 37 of Set 14 | dudinka
# Processing Record 38 of Set 14 | nichinan
# Processing Record 39 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 40 of Set 14 | omboue
# Processing Record 41 of Set 14 | pisco
# Processing Record 42 of Set 14 | praia da vitoria
# Processing Record 43 of Set 14 | tymovskoye
# Processing Record 44 of Set 14 | chumikan
# Processing Record 45 of Set 14 | aktash
# Processing Record 46 of Set 14 | jasdan
# Processing Record 47 of Set 14 | hakkari
# Processing Record 48 of Set 14 | cuamba
# Processing Record 49 of Set 14 | arman
# Processing Record 50 of Set 14 | manuk mangkaw
# Processing Record 1 of Set 15 | pitanga
# Processing Record 2 of Set 15 | kyaikkami
# Processing Record 3 of Set 15 | xining
# Processing Record 4 of Set 15 | tsabong
# Processing Record 5 of Set 15 | abu dhabi
# Processing Record 6 of Set 15 | progreso
# Processing Record 7 of Set 15 | lons-le-saunier
# Processing Record 8 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 9 of Set 15 | benicarlo
# Processing Record 10 of Set 15 | santo antonio do ica
# Processing Record 11 of Set 15 | tala
# Processing Record 12 of Set 15 | missungwi
# Processing Record 13 of Set 15 | nautla
# Processing Record 14 of Set 15 | velizh
# Processing Record 15 of Set 15 | acaponeta
# Processing Record 16 of Set 15 | sekoma
# Processing Record 17 of Set 15 | ilhabela
# Processing Record 18 of Set 15 | alberton
# Processing Record 19 of Set 15 | chapais
# Processing Record 20 of Set 15 | tougan
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | porto torres
# Processing Record 23 of Set 15 | amapa
# Processing Record 24 of Set 15 | birao
# Processing Record 25 of Set 15 | rusne
# Processing Record 26 of Set 15 | uzventis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Kodiak  57.7900 -152.4072     44.11        76          75
# 1            Butaritari   3.0707  172.7902     81.46        79          88
# 2                Narsaq  60.9167  -46.0500     43.02        79          65
# 3              Lalmohan  22.3384   90.7419     81.37        81          72
# 4                Avarua -21.2078 -159.7750     82.45        74          20
# 5                Atuona  -9.8000 -139.0333     78.31        81         100
# 6           Exaplatanos  40.9772   22.1250     56.21        94          98
# 7                Bonoua   5.2741   -3.5950     83.82        89          78
# 8                  Fare -16.7000 -151.0167     80.96        72           7
# 9  Nikolayevsk-Na-Amure  53.1406  140.7300     36.05        87          99
#
#    Wind Speed Country Current Description
# 0       19.57      US       broken clouds
# 1       13.35      KI          light rain
# 2        2.15      GL       broken clouds
# 3        8.99      BD       broken clouds
# 4        5.75      CK          few clouds
# 5       12.73      PF     overcast clouds
# 6        1.99      GR     overcast clouds
# 7        4.12      CI          light rain
# 8        9.24      PF           clear sky
# 9        3.22      RU     overcast clouds

# %%
# Reorder the columns

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Kodiak      US  57.7900 -152.4072     44.11        76
# 1            Butaritari      KI   3.0707  172.7902     81.46        79
# 2                Narsaq      GL  60.9167  -46.0500     43.02        79
# 3              Lalmohan      BD  22.3384   90.7419     81.37        81
# 4                Avarua      CK -21.2078 -159.7750     82.45        74
# 5                Atuona      PF  -9.8000 -139.0333     78.31        81
# 6           Exaplatanos      GR  40.9772   22.1250     56.21        94
# 7                Bonoua      CI   5.2741   -3.5950     83.82        89
# 8                  Fare      PF -16.7000 -151.0167     80.96        72
# 9  Nikolayevsk-Na-Amure      RU  53.1406  140.7300     36.05        87
#
#    Cloudiness  Wind Speed Current Description
# 0          75       19.57       broken clouds
# 1          88       13.35          light rain
# 2          65        2.15       broken clouds
# 3          72        8.99       broken clouds
# 4          20        5.75          few clouds
# 5         100       12.73     overcast clouds
# 6          98        1.99     overcast clouds
# 7          78        4.12          light rain
# 8           7        9.24           clear sky
# 9          99        3.22     overcast clouds

# %%
# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
